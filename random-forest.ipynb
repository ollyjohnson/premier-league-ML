# %%
import pandas as pd

# %%
matches = pd.read_csv('clean-matches.csv', index_col=0)

# %%
matches.shape
# Out:
# (12406, 7)

# %%
matches["Date"] = pd.to_datetime(matches["Date"], format='mixed', errors='coerce')

# %%
matches ["opponent"] = matches["Away"].astype("category").cat.codes
matches ["home_code"] = matches["Home"].astype("category").cat.codes
matches["day_code"] = matches["Date"].dt.day_of_week
matches["target"] = (matches["FTR"] == "H").astype(int)

# %%
matches
# Out:
#                  Wk       Date                   Home  HomeGoals  AwayGoals  \
# Season_End_Year
# 1993              1 1992-08-15          Coventry City          2          1
# 1993              1 1992-08-15           Leeds United          2          1
# 1993              1 1992-08-15          Sheffield Utd          2          1
# 1993              1 1992-08-15         Crystal Palace          3          3
# 1993              1 1992-08-15                Arsenal          2          4
# ...              ..        ...                    ...        ...        ...
# 2024             38 2024-05-19                Arsenal          2          1
# 2024             38 2024-05-19                Chelsea          2          1
# 2024             38 2024-05-19         ManchesterCity          3          1
# 2024             38 2024-05-19  BrightonandHoveAlbion          0          2
# 2024             38 2024-05-19              Brentford          2          4
#
#                            Away FTR  opponent  home_code  day_code  target
# Season_End_Year
# 1993              Middlesbrough   H        29         17         5       1
# 1993                  Wimbledon   H        49         26         5       1
# 1993             Manchester Utd   H        28         44         5       1
# 1993                  Blackburn   D         4         18         5       0
# 1993               Norwich City   A        31          0         5       0
# ...                         ...  ..       ...        ...       ...     ...
# 2024                    Everton   H        18          0         6       1
# 2024                Bournemouth   H         7         16         6       1
# 2024                   West Ham   H        47         32         6       1
# 2024             Manchester Utd   A        28         12         6       0
# 2024              Newcastle Utd   A        30         10         6       0
#
# [12406 rows x 11 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10,random_state=42)

# %%
train = matches[matches["Date"] < "2024-01-01"]
test = matches[matches["Date"] >= "2024-01-01"]

# %%
predictors = ["opponent", "home_code", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=42)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6630434782608695

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          73  30
# 1          32  49

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# np.float64(0.620253164556962)

# %%
grouped_matches = matches.groupby("Home")

# %%
group = grouped_matches.get_group("Arsenal")
group
# Out:
#                  Wk       Date     Home  HomeGoals  AwayGoals  \
# Season_End_Year
# 1993              1 1992-08-15  Arsenal          2          4
# 1993              4 1992-08-26  Arsenal          2          0
# 1993              5 1992-08-29  Arsenal          2          1
# 1993              8 1992-12-09  Arsenal          0          1
# 1993             10 1992-09-28  Arsenal          1          0
# ...              ..        ...      ...        ...        ...
# 2024             29 2024-04-23  Arsenal          5          0
# 2024             31 2024-04-03  Arsenal          2          0
# 2024             33 2024-04-14  Arsenal          0          2
# 2024             36 2024-05-04  Arsenal          3          0
# 2024             38 2024-05-19  Arsenal          2          1
#
#                             Away FTR  opponent  home_code  day_code  target
# Season_End_Year
# 1993                Norwich City   A        31          0         5       0
# 1993             Oldham Athletic   H        33          0         2       1
# 1993              Sheffield Weds   H        38          0         5       1
# 1993                   Blackburn   A         4          0         2       0
# 1993             Manchester City   H        27          0         0       1
# ...                          ...  ..       ...        ...       ...     ...
# 2024                     Chelsea   H        14          0         1       1
# 2024                  Luton Town   H        26          0         2       1
# 2024                 Aston Villa   A         1          0         6       0
# 2024                 Bournemouth   H         7          0         5       1
# 2024                     Everton   H        18          0         6       1
#
# [614 rows x 11 columns]

# %%
def rolling_avg(group,cols,new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["HomeGoals", "AwayGoals", "target"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_avg(group,cols,new_cols)
# Out:
#                  Wk       Date     Home  HomeGoals  AwayGoals  \
# Season_End_Year
# 1993              4 1992-08-26  Arsenal          2          0
# 1993              5 1992-08-29  Arsenal          2          1
# 1993             10 1992-09-28  Arsenal          1          0
# 1993             13 1992-10-24  Arsenal          2          0
# 1993             17 1992-11-28  Arsenal          0          1
# ...              ..        ...      ...        ...        ...
# 2024             31 2024-04-03  Arsenal          2          0
# 2024             33 2024-04-14  Arsenal          0          2
# 2024             29 2024-04-23  Arsenal          5          0
# 2024             36 2024-05-04  Arsenal          3          0
# 2024             38 2024-05-19  Arsenal          2          1
#
#                             Away FTR  opponent  home_code  day_code  target  \
# Season_End_Year
# 1993             Oldham Athletic   H        33          0         2       1
# 1993              Sheffield Weds   H        38          0         5       1
# 1993             Manchester City   H        27          0         0       1
# 1993                     Everton   H        18          0         5       1
# 1993              Manchester Utd   A        28          0         5       0
# ...                          ...  ..       ...        ...       ...     ...
# 2024                  Luton Town   H        26          0         2       1
# 2024                 Aston Villa   A         1          0         6       0
# 2024                     Chelsea   H        14          0         1       1
# 2024                 Bournemouth   H         7          0         5       1
# 2024                     Everton   H        18          0         6       1
#
#                  HomeGoals_rolling  AwayGoals_rolling  target_rolling
# Season_End_Year
# 1993                      2.333333           1.666667        0.666667
# 1993                      2.333333           1.333333        0.666667
# 1993                      2.000000           1.666667        0.666667
# 1993                      1.666667           0.333333        1.000000
# 1993                      1.666667           0.333333        1.000000
# ...                            ...                ...             ...
# 2024                      3.000000           1.000000        1.000000
# 2024                      2.666667           0.666667        1.000000
# 2024                      1.333333           1.000000        0.666667
# 2024                      2.333333           0.666667        0.666667
# 2024                      2.666667           0.666667        0.666667
#
# [611 rows x 14 columns]

# %%
matches_rolling = matches.groupby("Home").apply(lambda x: rolling_avg(x,cols,new_cols))
matches_rolling
# Out:
# C:\Users\ollyj\AppData\Local\Temp\ipykernel_16272\1775988057.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("Home").apply(lambda x: rolling_avg(x,cols,new_cols))
#                          Wk       Date     Home  HomeGoals  AwayGoals  \
# Home    Season_End_Year
# Arsenal 1993              4 1992-08-26  Arsenal          2          0
#         1993              5 1992-08-29  Arsenal          2          1
#         1993             10 1992-09-28  Arsenal          1          0
#         1993             13 1992-10-24  Arsenal          2          0
#         1993             17 1992-11-28  Arsenal          0          1
# ...                      ..        ...      ...        ...        ...
# Wolves  2023             31 2023-04-15   Wolves          2          0
#         2023             33 2023-04-25   Wolves          2          0
#         2023             37 2023-05-20   Wolves          1          1
#         2023             35 2023-06-05   Wolves          1          0
#         2023             30 2023-08-04   Wolves          1          0
#
#                                     Away FTR  opponent  home_code  day_code  \
# Home    Season_End_Year
# Arsenal 1993             Oldham Athletic   H        33          0         2
#         1993              Sheffield Weds   H        38          0         5
#         1993             Manchester City   H        27          0         0
#         1993                     Everton   H        18          0         5
#         1993              Manchester Utd   A        28          0         5
# ...                                  ...  ..       ...        ...       ...
# Wolves  2023                   Brentford   H         9         61         5
#         2023              Crystal Palace   H        16         61         1
#         2023                     Everton   D        18         61         5
#         2023                 Aston Villa   H         1         61         0
#         2023                     Chelsea   H        14         61         4
#
#                          target  HomeGoals_rolling  AwayGoals_rolling  \
# Home    Season_End_Year
# Arsenal 1993                  1           2.333333           1.666667
#         1993                  1           2.333333           1.333333
#         1993                  1           2.000000           1.666667
#         1993                  1           1.666667           0.333333
#         1993                  0           1.666667           0.333333
# ...                         ...                ...                ...
# Wolves  2023                  1           2.000000           1.333333
#         2023                  1           2.000000           0.000000
#         2023                  0           1.666667           0.000000
#         2023                  1           1.666667           0.333333
#         2023                  1           1.333333           0.333333
#
#                          target_rolling
# Home    Season_End_Year
# Arsenal 1993                   0.666667
#         1993                   0.666667
#         1993                   0.666667
#         1993                   1.000000
#         1993                   1.000000
# ...                                 ...
# Wolves  2023                   0.666667
#         2023                   1.000000
#         2023                   1.000000
#         2023                   0.666667
#         2023                   0.666667
#
# [12220 rows x 14 columns]

# %%
matches_rolling = matches_rolling.droplevel("Home")
matches_rolling
# Out:
#                  Wk       Date     Home  HomeGoals  AwayGoals  \
# Season_End_Year
# 1993              4 1992-08-26  Arsenal          2          0
# 1993              5 1992-08-29  Arsenal          2          1
# 1993             10 1992-09-28  Arsenal          1          0
# 1993             13 1992-10-24  Arsenal          2          0
# 1993             17 1992-11-28  Arsenal          0          1
# ...              ..        ...      ...        ...        ...
# 2023             31 2023-04-15   Wolves          2          0
# 2023             33 2023-04-25   Wolves          2          0
# 2023             37 2023-05-20   Wolves          1          1
# 2023             35 2023-06-05   Wolves          1          0
# 2023             30 2023-08-04   Wolves          1          0
#
#                             Away FTR  opponent  home_code  day_code  target  \
# Season_End_Year
# 1993             Oldham Athletic   H        33          0         2       1
# 1993              Sheffield Weds   H        38          0         5       1
# 1993             Manchester City   H        27          0         0       1
# 1993                     Everton   H        18          0         5       1
# 1993              Manchester Utd   A        28          0         5       0
# ...                          ...  ..       ...        ...       ...     ...
# 2023                   Brentford   H         9         61         5       1
# 2023              Crystal Palace   H        16         61         1       1
# 2023                     Everton   D        18         61         5       0
# 2023                 Aston Villa   H         1         61         0       1
# 2023                     Chelsea   H        14         61         4       1
#
#                  HomeGoals_rolling  AwayGoals_rolling  target_rolling
# Season_End_Year
# 1993                      2.333333           1.666667        0.666667
# 1993                      2.333333           1.333333        0.666667
# 1993                      2.000000           1.666667        0.666667
# 1993                      1.666667           0.333333        1.000000
# 1993                      1.666667           0.333333        1.000000
# ...                            ...                ...             ...
# 2023                      2.000000           1.333333        0.666667
# 2023                      2.000000           0.000000        1.000000
# 2023                      1.666667           0.000000        1.000000
# 2023                      1.666667           0.333333        0.666667
# 2023                      1.333333           0.333333        0.666667
#
# [12220 rows x 14 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#        Wk       Date     Home  HomeGoals  AwayGoals             Away FTR  \
# 0       4 1992-08-26  Arsenal          2          0  Oldham Athletic   H
# 1       5 1992-08-29  Arsenal          2          1   Sheffield Weds   H
# 2      10 1992-09-28  Arsenal          1          0  Manchester City   H
# 3      13 1992-10-24  Arsenal          2          0          Everton   H
# 4      17 1992-11-28  Arsenal          0          1   Manchester Utd   A
# ...    ..        ...      ...        ...        ...              ...  ..
# 12215  31 2023-04-15   Wolves          2          0        Brentford   H
# 12216  33 2023-04-25   Wolves          2          0   Crystal Palace   H
# 12217  37 2023-05-20   Wolves          1          1          Everton   D
# 12218  35 2023-06-05   Wolves          1          0      Aston Villa   H
# 12219  30 2023-08-04   Wolves          1          0          Chelsea   H
#
#        opponent  home_code  day_code  target  HomeGoals_rolling  \
# 0            33          0         2       1           2.333333
# 1            38          0         5       1           2.333333
# 2            27          0         0       1           2.000000
# 3            18          0         5       1           1.666667
# 4            28          0         5       0           1.666667
# ...         ...        ...       ...     ...                ...
# 12215         9         61         5       1           2.000000
# 12216        16         61         1       1           2.000000
# 12217        18         61         5       0           1.666667
# 12218         1         61         0       1           1.666667
# 12219        14         61         4       1           1.333333
#
#        AwayGoals_rolling  target_rolling
# 0               1.666667        0.666667
# 1               1.333333        0.666667
# 2               1.666667        0.666667
# 3               0.333333        1.000000
# 4               0.333333        1.000000
# ...                  ...             ...
# 12215           1.333333        0.666667
# 12216           0.000000        1.000000
# 12217           0.000000        1.000000
# 12218           0.333333        0.666667
# 12219           0.333333        0.666667
#
# [12220 rows x 14 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < "2024-01-01"]
    test = data[data["Date"] >= "2024-01-01"]
    rf = RandomForestClassifier(n_estimators=50, min_samples_split=10,random_state=42)
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)    
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# np.float64(0.6825396825396826)

# %%
combined = combined.merge(matches_rolling[["Home", "Date", "Away", "FTR"]], left_index=True, right_index=True)
combined
# Out:
#        actual  predicted                    Home       Date            Away  \
# 602         1          1                 Arsenal 2024-01-20  Crystal Palace
# 603         1          0                 Arsenal 2024-02-04       Liverpool
# 604         1          1                 Arsenal 2024-02-24   Newcastle Utd
# 605         1          1                 Arsenal 2024-03-09       Brentford
# 606         1          1                 Arsenal 2024-04-03      Luton Town
# ...       ...        ...                     ...        ...             ...
# 12047       0          0  WolverhamptonWanderers 2024-04-06        West Ham
# 12048       0          0  WolverhamptonWanderers 2024-04-20         Arsenal
# 12049       0          0  WolverhamptonWanderers 2024-04-24     Bournemouth
# 12050       1          0  WolverhamptonWanderers 2024-04-27      Luton Town
# 12051       0          0  WolverhamptonWanderers 2024-05-11  Crystal Palace
#
#       FTR
# 602     H
# 603     H
# 604     H
# 605     H
# 606     H
# ...    ..
# 12047   A
# 12048   A
# 12049   A
# 12050   H
# 12051   A
#
# [184 rows x 6 columns]
